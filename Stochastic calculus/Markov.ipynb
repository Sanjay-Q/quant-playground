# %% [markdown]
# *The future depends only on the present, not the full past this is called markov property or memoryless
#
# P(Xt+1​=j∣Xt​=i,Xt−1​,…,X0​)=P(Xt+1​=j∣Xt​=i)
#
# *Markov said:
# Instead of remembering EVERYTHING,
# store only the current state.
# That state summarizes relevant information.
# This is enormously powerful.
#
# *Suppose you're talking to someone.
# To predict next sentence:
# you don't need every sentence since birth
# recent context is enough
# That is Markov intuition.
# Modern AI language models evolved from similar probabilistic sequence ideas.

# %% [markdown]
# HIDDEN MARKOV MODELS
#
# Hidden layer:
# Z1→Z2→Z3
# 	​
# Observed layer:X1, X2, X3
# 	where each:Xt depends on hidden state Zt
#
# A Hidden Markov Model (HMM) is a statistical model where:
# the system moves between hidden states following a Markov process
# each hidden state generates observable outputs probabilistically
#
# Formula:P(Zt+1 ​∣ Zt​,Zt−1​,…)=P(Zt+1 ​∣ Zt​)
#
# A model where you cannot directly see the true state of the system, but you can infer it from observable data.
# Bull market : Strong growth
# Bear market : fear	​
# sidewise : uncertainty we cant directly observe the sentiments but we can observe the data
